# %%
pip install git+https://github.com/openai/whisper.git

# %%
# !sudo apt update && sudo apt install ffmpeg

# %%
# !whisper "XXX.mp3" --model medium

# %%
# Paso 1: Montar tu Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Paso 2: Guardar el archivo en tu Drive
# Asegúrate de reemplazar 'nombre-del-archivo.json' con el nombre de tu archivo.
# La ruta a tu Drive siempre comienza con '/content/drive/MyDrive/'
# !cp XXX.json '/content/drive/MyDrive/TFG_2025/Entrevistas/'

# %%
# !cp XXX.txt '/content/drive/MyDrive/TFG_2025/Entrevistas/'
